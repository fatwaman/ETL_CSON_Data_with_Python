# %% [markdown]
# # **Update data 4G Main KPI CSON**

# %% [markdown]
# I used this code to update my database in PostgreSQL for Daily 4G KPI Performance

# %%
# Import required library

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

from datetime import datetime, timedelta, date
from sqlalchemy import create_engine

# %% [markdown]
# ### **1. Open and Append Data File(s)**

# %%
# 1. Define the path to your Downloads folder
path = os.path.expanduser("~/Downloads/")

# 2. Define the pattern to search for
search_pattern = os.path.join(path, "*4G CSON Dashboard*.csv")  # The '*' means "anything before or after this text"

# 3. List all matching files
target_files = glob.glob(search_pattern)

# 4. Combine the data from all files into a single DataFrame
df_list = []

for file in target_files:
    temp_df = pd.read_csv(file, dtype={33: float, 40: float, 57: str})  # Read each file, specifying data types for certain columns
    # temp_df['source_file'] = os.path.basename(file)                   # Optional: Add a column to track which date the data came from
    df_list.append(temp_df)                                             # Append data
    
# Transform: Combine all 4G files into one
df = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# ### **2. Extracting and Transform Data File(s)**

# %%
# Rename columns to make easier to work with
df.rename(columns={"DATETIME" : "DATE"}, inplace=True)

# Convert DATE column to datetime format to YYYY-MM-DD
df['DATE'] = pd.to_datetime(df['DATE'], format='%d/%m/%y', errors='coerce')

# df["DATE"] = pd.to_datetime(df["DATE"])
# df['DATE'] = pd.to_datetime(df['DATE'], dayfirst=True, errors='coerce')
# df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce').dt.date
# df['DATE'] = df['DATE'].dt.strftime('%Y-%m-%d')

# Sort Columns
df = df[['DATE',
         'REGION',
         'DISTRICT',
         'SITENAME',
         'CELL',
         'CI',
         'EARFCN',
         'Collection Interval',
         'nonbhinterference',
         'dl_prb_utilization_rate_relpaydl',
         'dl_prb_utilization_rate_relpaydl_num',
         'dl_prb_utilization_rate_relpaydl_Denum',
         'ul_prb_utilization_rate_relpaydl',
         'ul_prb_utilization_rate_relpaydl_Num',
         'ul_prb_utilization_rate_relpaydl Den',
         'dl_traffic_volume_mbyte',
         'ul_traffic_volume_mbyte',
         'user_downlink_throughput kbps',
         'user_downlink_throughput_num',
         'user_downlink_throughput_den',
         'user_uplink_throughput kbps',
         'user_uplink_throughput_num',
         'user_uplink_throughput_Den',
         'Average RRC Connection Users',
         'Maximum RRC Connection Users beCloud Added',
         'VoLTE Traffic (Erlang)',
         'SRVCC HO Execution Success to GSM',
         'SRVCC HO Execution Attempt to GSM',
         'SRVCC HO Fails to GSM',
         'SRVCC HO Preparation Success to GSM',
         'SRVCC HO Preparation Attempt to GSM',
         'Average CQI Numerator',
         'Average CQI Denominator',
         'numerator_call_setup_success_rate',
         'numerator_csfb_preparation_success_rate',
         'numerator_e_rab_setup_success_rate',
         'numerator_intra_frequency_handover_out_success_rate',
         'numerator_Radio_Network_Availability_Rate',
         'numerator_service_drop_rate_including_mme',
         'num_inter_frequency_handover_out_success_rate',
         'denumerator_call_setup_success_rate',
         'denumerator_csfb_preparation_success_rate',
         'denumerator_e_rab_setup_success_rate',
         'denumerator_intra_frequency_handover_out_success_rate',
         'denumerator_Radio_Network_Availability_Rate',
         'denumerator_service_drop_rate_including_mme',
         'denum_inter_frequency_handover_out_success_rate',
         'cell_downlink_throughput kbps',
         'cell_downlink_through',
         'cell_downlink_throughput Den',
         'cell_uplink_throughput kbps',
         'cell_uplink_throughput_num',
         'cell_uplink_throughput_Den',
         'VoLTE E-RAB Drop',
         'VoLTE E-RAB Total Release',
         'RRC_Setup_Success_Rate  Num',
         'RRC_Setup_Success_Rate  Denum',
         'RACH Setup Success',
         'RACH Setup Attempt',
         'CBRA Success Rate',
         'CBRA Success Rate Den',
         'CFRA Success Rate Num',
         'CFRA Success Rate Den',
         'Rach Failure',
         'Rach Failure due cellRange',
         'Rach Failure due cellRange%',
         'CQI>=7 Num',
         'CQI>=7 Denum',
         'Active User HWI',
         'RSSI']]

# Sort the DataFrame by multiple columns in ascending order
df = df.sort_values(
    by=['DATE', 'REGION', 'DISTRICT', 'SITENAME', 'CELL'], 
    ascending=True
)

# %%
# Convert some columns to integer, but first convert to numeric and coerce errors to NaN, then convert to Int64 which allows for NA values
int_columns = [
    'CI',
    'EARFCN',
    'Collection Interval',
    'dl_prb_utilization_rate_relpaydl_num',
    'dl_prb_utilization_rate_relpaydl_Denum',
    'ul_prb_utilization_rate_relpaydl_Num',
    'ul_prb_utilization_rate_relpaydl Den',
    'SRVCC HO Execution Success to GSM',
    'SRVCC HO Execution Attempt to GSM',
    'SRVCC HO Fails to GSM',
    'SRVCC HO Preparation Success to GSM',
    'SRVCC HO Preparation Attempt to GSM',
    'Average CQI Numerator',
    'Average CQI Denominator',
    'numerator_e_rab_setup_success_rate',
    'numerator_intra_frequency_handover_out_success_rate',
    'numerator_Radio_Network_Availability_Rate',
    'numerator_service_drop_rate_including_mme',
    'num_inter_frequency_handover_out_success_rate',
    'denumerator_e_rab_setup_success_rate',
    'denumerator_intra_frequency_handover_out_success_rate',
    'denumerator_Radio_Network_Availability_Rate',
    'denumerator_service_drop_rate_including_mme',
    'denum_inter_frequency_handover_out_success_rate',
    'VoLTE E-RAB Drop',
    'VoLTE E-RAB Total Release',
    'RRC_Setup_Success_Rate  Num',
    'RRC_Setup_Success_Rate  Denum',
    'RACH Setup Success',
    'RACH Setup Attempt',
    'CBRA Success Rate',
    'CBRA Success Rate Den',
    'CFRA Success Rate Num',
    'CFRA Success Rate Den',
    'Rach Failure',
    'Rach Failure due cellRange',
    'CQI>=7 Num',
    'CQI>=7 Denum',
    'Active User HWI'
]

# 2. Loop through the list and apply the conversion
for col in int_columns:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce').astype('Int64')

# %% [markdown]
# ### **3. Connect to PostgreSQL Engine**

# %%
########################################################################################
# WARNING: Make sure the values ​​below are not published publicly or uploaded to the repository,
# because this is sensitive information that could be used to access our database.
# For larger projects, it's best to use environment variables or configuration files that aren't uploaded to the repository to store this information.
########################################################################################

DB_USER = "postgres"
DB_PASS = "12345"
DB_HOST = "localhost"
DB_PORT = "5432"
DB_NAME = "postgres"

# %%
# Create engine to connect to PostgreSQL database using SQLAlchemy

engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}")

# %% [markdown]
# ### **4. Append Data to existing database**

# %%
# Function to use PostgreSQL's COPY command for faster bulk inserts

import csv
from io import StringIO

def psql_insert_copy(table, conn, keys, data_iter):
    # gets a DBAPI connection from the sqlalchemy engine
    dbapi_conn = conn.connection
    with dbapi_conn.cursor() as cur:
        s_buf = StringIO()
        writer = csv.writer(s_buf)
        writer.writerows(data_iter)
        s_buf.seek(0)

        columns = ', '.join('"{}"'.format(k) for k in keys)
        if table.schema:
            table_name = '{}.{}'.format(table.schema, table.name)
        else:
            table_name = table.name

        sql = 'COPY "{}" ({}) FROM STDIN WITH CSV'.format(table_name, columns) # Add double quotes around table name to handle special characters or reserved keywords
        cur.copy_expert(sql=sql, file=s_buf)

# %%
# Import data to a table in the PostgreSQL database using the to_sql method from pandas and chunking to avoid memory issues

# 1. Define your chunk size (100k rows is usually safe for 16GB RAM)
chunk_size = 100000

# 2. Loop through the dataframe in pieces
for i in range(0, len(df), chunk_size):
    # Select the current chunk
    df_chunk = df.iloc[i : i + chunk_size]
    
    # Upload this chunk using the fast COPY method
    df_chunk.to_sql(
        name="4G_CSON_KPI_202603", 
        con=engine, 
        if_exists="append", 
        index=False, 
        method=psql_insert_copy
    )
    
    print(f"Successfully uploaded rows {i} to {min(i + chunk_size, len(df))}")

print("--- All Data Uploaded Successfully ---")

# %% [markdown]
# ### **5. Data verification using line chart from PostgreSQL**

# %% [markdown]
# ##### **5.1 Create SQL Query**

# %%
# SQL Query to get the count of records per date
query = """
SELECT "DATE", COUNT(*) as "Num of Records" 
FROM "4G_CSON_KPI_202603" 
GROUP BY "DATE" 
ORDER BY "DATE" ASC
"""

# %%
# Load the query into a DataFrame
df_counts = pd.read_sql(query, engine)

# %% [markdown]
# ##### **5.2 Create line chart**

# %%
# Create the Line Chart
plt.figure(figsize=(12, 6))
plt.plot(df_counts['DATE'], df_counts['Num of Records'], marker='o', color='#0077B5', linewidth=2)

# Styling
plt.title('Daily Data Volume - 4G CSON KPI', fontsize=14, fontweight='bold')
plt.xlabel('Date', fontsize=12)
plt.ylabel('Number of Records (Rows)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(rotation=90)
plt.tight_layout()
# plt.ylim(bottom=0)

# Display/Save
plt.show()
